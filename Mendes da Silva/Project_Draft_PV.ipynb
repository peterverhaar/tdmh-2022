# %% [markdown]
# ## Import necessary packages and NLTK resources

# %% [markdown]
# Intall `stanza` if necessary. Remove the hash before you run the code below.

# %%
#pip install -U stanza

# %%
import os
import re
import nltk
from nltk import word_tokenize , sent_tokenize , pos_tag
from tdmh import *
from os.path import join
import stanza

# %%
import ssl

try:
    _create_unverified_https_context = ssl._create_unverified_context
except AttributeError:
    pass
else:
    ssl._create_default_https_context = _create_unverified_https_context

nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
nltk.download('tagsets')
nltk.download('wordnet')
nltk.download('sentiwordnet')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/verhaarpaf/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /Users/verhaarpaf/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package tagsets to
# [nltk_data]     /Users/verhaarpaf/nltk_data...
# [nltk_data]   Package tagsets is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/verhaarpaf/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package sentiwordnet to
# [nltk_data]     /Users/verhaarpaf/nltk_data...
# [nltk_data]   Package sentiwordnet is already up-to-date!
# True

# %% [markdown]
# ## Create a list of all the files in the Corpus
#
# The code below assumes that all the text files are in subfolders underneath 'Corpus', e.g. 'Corpus/Ricardo_Reis/RR_Sob_a_leve_tutela.txt' or 'Corpus/Fernando_Pessoa/FP_Autopsicografia.txt'.
#
# The list `files()` contains the full paths to these texts.

# %%
texts = []
dir = r'Corpus'
files = []

for entry in os.listdir(dir):
    # dir + subdirectory
    path = os.path.join(dir,entry)
    if os.path.isdir(path):
        
        for file in os.listdir(path):
            # dir + subdirectory + file 
            file_path = join(path,file)
            texts.append( file_path )
            if re.search( r'txt$' , file_path ):
                print( file_path )
                files.append(file_path)
# Out:
# Corpus/Ricardo_Reis/RR_Sob_a_leve_tutela.txt
# Corpus/Ricardo_Reis/RR_Uns_com_os_olhos_postos_no_passado.txt
# Corpus/Ricardo_Reis/RR_Prefiro_rosas_meu_amor_à_pátria.txt
# Corpus/Álvaro_de_Campos/AdA_Tabacaria.txt
# Corpus/Álvaro_de_Campos/AdA_Ode_Triunfal.txt
# Corpus/Alberto_Caeiro/AC_V_Guardador_de_Rebanhos.txt
# Corpus/Alberto_Caeiro/AC_IX_Guardador_de_Rebanhos.txt
# Corpus/Fernando_Pessoa/FP_Quando_era_criança.txt
# Corpus/Fernando_Pessoa/FP_Autopsicografia.txt
# Corpus/Fernando_Pessoa/FP_Isto.txt
# Corpus/Fernando_Pessoa/FP_Quando_as_crianças_brincam.txt
# Corpus/Fernando_Pessoa/FP_Gato_que_brincas_na_rua.txt

# %% [markdown]
# ## Create an Stanza NLP object to analyse the Portuguese texts

# %% [markdown]
# We use the Portuguese ('pt') model.

# %%
stanza.download('pt')       
nlp = stanza.Pipeline('pt')

def get_title(path):
    title = os.path.basename(path)
    if re.search( r'txt$' , title ):
        # Remove txt extension
        title = title[ :title.index('.txt') ]
        # remove commas and dots
        title = re.sub( r'[.,]' , '' , title )
    return title
# Out:
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.3.0.json:   0%|   …
# 2022-04-10 14:45:11 INFO: Downloading default packages for language: pt (Portuguese)...
# 2022-04-10 14:45:11 INFO: File exists: /Users/verhaarpaf/stanza_resources/pt/default.zip.
# 2022-04-10 14:45:13 INFO: Finished downloading models and saved to /Users/verhaarpaf/stanza_resources.
# 2022-04-10 14:45:13 INFO: Loading these models for language: pt (Portuguese):
# =======================
# | Processor | Package |
# -----------------------
# | tokenize  | bosque  |
# | mwt       | bosque  |
# | pos       | bosque  |
# | lemma     | bosque  |
# | depparse  | bosque  |
# =======================
#
# 2022-04-10 14:45:13 INFO: Use device: cpu
# 2022-04-10 14:45:13 INFO: Loading: tokenize
# 2022-04-10 14:45:13 INFO: Loading: mwt
# 2022-04-10 14:45:13 INFO: Loading: pos
# 2022-04-10 14:45:13 INFO: Loading: lemma
# 2022-04-10 14:45:13 INFO: Loading: depparse
# 2022-04-10 14:45:13 INFO: Done loading processors!

# %% [markdown]
# ## Create the data for each poem
#
# Using the `files` list that was created earlier, wee create data for each poem successevely.

# %%
from tdmh import *
import re
from nltk.tokenize import word_tokenize

out = open( 'data.csv' , 'w' , encoding='utf-8' )
out.write('title,heteronym,tokens,types,adjectives,adverbs,verbs,nouns\n')

pos_tags = ['ADJ' , 'ADV' , 'VERB' , 'NOUN']


for text in files:
    freq_vocabulary = dict()
    freq_pos = dict()
    tagged_words = dict()

    # we extract the title from the full path
    # using the get_title() function
    print( f'Analysing {get_title(text)} ... ')
    
    ## We also extract the heternym form the full path
    # The heteronym can be found in the second part
    # of the path
    path = os.path.normpath(text)
    parts = path.split(os.sep)
    heteronym = parts[1].strip()
    print( f'Heteronym: {heteronym}')
    
    with open( text , encoding = 'utf-8') as poem:
        full_text = poem.read()
        nr_sentences =  0
        nr_tokens = 0 
        
        # the nlp() function in NLP recognises 
        # sentences, words and POS tags
        
        doc = nlp(full_text)
    
        for sent in doc.sentences:
            nr_sentences += 1
               
            for word in sent.words:
                # words are in word.text
                # POS tags are saved as word.upos
                
                nr_tokens += 1
                word.text = word.text.lower()
                tagged_words[word.text] = word.upos
                freq_pos[ word.upos ] = freq_pos.get( word.upos ,0) +1
                freq_vocabulary[word.text] = freq_vocabulary.get(word.text,0) + 1
        
        words = list(freq_vocabulary.keys()) 
        print(f'The poem has {nr_tokens} words in total:')
        print(f'The poem has {len(words)} unique words (types):')
        print(words)
        
        print(f"There are { freq_pos.get('ADJ',0) } adjectives:")
        for word in tagged_words:
            if tagged_words[word] == 'ADJ':
                print( word )
        print(f"There are { freq_pos.get('ADV',0) } adverbs:")
        for word in tagged_words:
            if tagged_words[word] == 'ADV':
                print( word )
                
        print('\n\n')
        
        out.write(f"{get_title(text)},{heteronym},{nr_tokens}," )
        out.write(f"{len(words)},{freq_pos.get('ADJ',0)/nr_tokens}," )
        out.write(f"{freq_pos.get('ADV',0)/nr_tokens}")
        out.write(f"{freq_pos.get('VERB',0)/nr_tokens},{freq_pos.get('NOUN',0)/nr_tokens}")
        out.write('\n')
        
out.close()    
        

print('Done!')
# Out:
# Analysing RR_Sob_a_leve_tutela ...
# Heteronym: Ricardo_Reis
# The poem has 68 words in total:
# The poem has 44 unique words (types):
# ['sob', 'a', 'leve', 'tutela', 'de', 'deuses', 'descuidosos', ',', 'quero', 'gastar', 'as', 'concedidas', 'horas', 'esta', 'fadada', 'vida', '.', 'nada', 'podendo', 'contra', 'o', 'ser', 'que', 'me', 'fizeram', 'desejo', 'menos', 'haja', 'fado', 'dado', 'paz', 'por', 'destino', 'verdade', 'não', 'mais', ';', 'os', 'dão', 'e', 'nem', 'talvez', 'saibam', 'qual']
# There are 3 adjectives:
# leve
# descuidosos
# fadada
# There are 5 adverbs:
# nada
# não
# mais
# talvez
#
#
#
# Analysing RR_Uns_com_os_olhos_postos_no_passado ...
# Heteronym: Ricardo_Reis
# The poem has 98 words in total:
# The poem has 57 unique words (types):
# ['uns', ',', 'com', 'os', 'olhos', 'postos', 'em', 'o', 'passado', 'vêem', 'que', 'não', ';', 'outros', 'fitos', 'mesmos', 'futuro', 'pode', 'ver', 'se', '.', 'porque', 'tão', 'longe', 'ir', 'pôr', 'está', 'perto', '—', 'a', 'segurança', 'nossa', '?', 'este', 'é', 'dia', 'esta', 'hora', 'momento', 'isto', 'quem', 'somos', 'e', 'tudo', 'perene', 'flui', 'interminável', 'nos', 'confessa', 'nulos', 'mesmo', 'hausto', 'vivemos', 'morreremos', 'colhe', 'és', 'ele']
# There are 4 adjectives:
# mesmos
# perene
# interminável
# mesmo
# There are 5 adverbs:
# não
# tão
# longe
# perto
#
#
#
# Analysing RR_Prefiro_rosas_meu_amor_à_pátria ...
# Heteronym: Ricardo_Reis
# The poem has 117 words in total:
# The poem has 68 unique words (types):
# ['prefiro', 'rosas', ',', 'meu', 'amor', 'a', 'pátria', 'e', 'antes', 'magnólias', 'amo', 'que', 'glória', 'virtude', '.', 'logo', 'vida', 'me', 'não', 'canse', 'deixo', 'por', 'mim', 'passe', 'eu', 'fique', 'o', 'mesmo', 'importa', 'aquele', 'quem', 'já', 'nada', 'um', 'perca', 'outro', 'vença', 'se', 'aurora', 'raia', 'sempre', 'cada', 'ano', 'com', 'primavera', 'as', 'folhas', 'aparecem', 'outono', 'cessam', '?', 'resto', 'outras', 'coisas', 'os', 'humanos', 'acrescentam', 'aumentam', 'em', 'alma', 'salvo', 'desejo', 'de', 'indiferença', 'confiança', 'mole', 'hora', 'fugitiva']
# There are 2 adjectives:
# mole
# fugitiva
# There are 6 adverbs:
# antes
# logo
# não
# já
# sempre
#
#
#
# Analysing AdA_Tabacaria ...
# Heteronym: Álvaro_de_Campos
# The poem has 1783 words in total:
# The poem has 582 unique words (types):
# ['tabacaria', 'não', 'sou', 'nada', '.', 'nunca', 'serei', 'posso', 'querer', 'ser', 'a', 'parte', 'isso', ',', 'tenho', 'em', 'mim', 'todos', 'os', 'sonhos', 'de', 'o', 'mundo', 'janelas', 'meu', 'quarto', 'um', 'milhões', 'que', 'ninguém', 'sabe', 'quem', 'é', '(', 'e', 'se', 'soubessem', 'saberiam', '?', ')', 'dais', 'para', 'mistério', 'uma', 'rua', 'cruzada', 'constantemente', 'por', 'gente', 'inacessível', 'pensamentos', 'real', 'impossivelmente', 'certa', 'desconhecidamente', 'com', 'as', 'coisas', 'baixo', 'pedras', 'seres', 'morte', 'pôr', 'humidade', 'paredes', 'cabelos', 'brancos', 'homens', 'destino', 'conduzir', 'carroça', 'tudo', 'estrada', 'estou', 'hoje', 'vencido', 'como', 'soubesse', 'verdade', 'lúcido
 'patrícia', 'romana', 'nefasta', 'princesa', 'trovadores', 'gentilíssima', 'colorida', 'marquesa', 'século', 'dezoito', 'decotada', 'longínqua', 'cocote', 'célebre', 'tempo', 'nossos', 'pais', 'quê', 'moderno', 'concebo', 'bem', 'seja', 'for', 'sejas', 'inspirar', 'inspire', 'coração', 'balde', 'despejado', 'invocam', 'espíritos', 'invoco', 'encontro', 'chego', 'vejo', 'nitidez', 'absoluta', 'lojas', 'passeios', 'carros', 'passam', 'entes', 'vivos', 'vestidos', 'cruzam', 'cães', 'também', 'existem', 'isto', 'pesa', 'condenação', 'degredo', 'estrangeiro', 'vivi', 'estudei', 'amei', 'cri', 'mendigo', 'inveje', 'olho', 'cada ...
# There are 71 adjectives:
# quarto
# inacessível
# brancos
# lúcido
# perplexo
# grandes
# igual
# mesma
# futuras
# certo
# génios-para-si-mesmos
# altas
# nobres
# lúcidas
# realizáveis
# hipotético
# ardente
# cardíacos
# opaco
# alheio
# inteira
# solar
# pequena
# suja
# rápida
# mesmo
# nobre
# largo
# grega
# viva
# romana
# nefasta
# gentilíssima
# longínqua
# célebre
# moderno
# absoluta
# vivos
# estrangeiro
# possível
# errado
# pegada
# inofensivo
# sublime
# musical
# inúteis
# girante
# inútil
# plausível
# enérgico
# humano
# própria
# gozo
# sensitivo
# competente
# disposto
# feliz
# divino
# There are 112 adverbs:
# não
# nunca
# constantemente
# impossivelmente
# desconhecidamente
# hoje
# como
# mais
# dentro
# fora
# talvez
# lá
# só
# sim
# verdadeiramente
# ainda
# sempre
# antes
# bem
# também
# apenas
# aquém
# remexidamente
# logo
# já
# defronte
# mal
# depois
# tão
# trás
# enquanto
#
#
#
# Analysing AdA_Ode_Triunfal ...
# Heteronym: Álvaro_de_Campos
# The poem has 2349 words in total:
# The poem has 823 unique words (types):
# ['ode', 'triunfal', 'a', 'dolorosa', 'luz', 'de', 'as', 'grandes', 'lâmpadas', 'eléctricas', 'fábrica', 'tenho', 'febre', 'e', 'escrevo', '.', 'rangendo', 'os', 'dentes', ',', 'fera', 'para', 'beleza', 'isto', 'totalmente', 'desconhecida', 'antigos', 'ó', 'rodas', 'engrenagens', 'r-rrrrrr', 'rr', 'eterno', '!', 'forte', 'espasmo', 'retido', 'maquinismos', 'em', 'fúria', 'fora', 'dentro', 'mim', 'por', 'todos', 'meus', 'nervos', 'dissecados', 'todas', 'papilas', 'tudo', 'com', 'que', 'eu', 'sinto', 'lábios', 'secos', 'ruídos', 'modernos', 'vos', 'ouvir', 'demasiadamente', 'perto', 'arde', 'me', 'cabeça', 'querer', 'cantar', 'um', 'excesso', 'expressão', 'minhas', 'sensações', 'contemporâneo', 'vós', 'máquinas', 'olhando', 'motores', 'como', 'uma', 'natureza', 'tropical', '—', 'trópicos', 'humanos', 'ferro', 'fogo', 'força', 'canto', 'o', 'presente', 'também', 'passado', 'futuro', 'porque', 'é', 'todo', 'há', 'platão', 'virgílio', 'luzes', 'só', 'houve', 'outrora', 'foram', 'pedaços', 'alexandre', 'magno', 'século', 'talvez', 'cinquenta
# There are 166 adjectives:
# triunfal
# dolorosa
# grandes
# eléctricas
# eterno
# forte
# secos
# modernos
# contemporâneo
# tropical
# humanos
# só
# completo
# triunfante
# último-modelo
# estupenda
# negra
# artificial
# insaciável
# promíscua
# férreo
# cosmopolita
# estrénuos
# transportadora-de-cargas
# lúbrico
# lento
# ciciante
# monótono
# europeias
# produtoras
# úteis
# ruidosas
# nova
# novos
# internacional
# transatlântica
# febris
# evidentes
# aristocráticos
# dúbias
# felizes
# paternais
# interessante
# feminil
# falsa
# lentos
# elegante
# maravilhosa
# deliciosos
# financeiros
# diplomáticos
# usuais
# lúcidos
# políticos
# sinceros
# passez
# segunda
# fresco
# amarelos
# branca
# agrícola
# calmos
# últimos
# inúteis
# eléctricos
# diferente
# mortíferos
# banais
# modernas
# contemporâneas
# actual
# próxima
# imediato
# metálica
# flutuantes
# turbulenta
# bela
# interessantíssima
# ministeriais
# natural
# belo
# misteriosa
# antigo
# solene
# mesmo
# real
# deliciosa
# moderno
# alto
# sexual
# cheio
# plena
# quotidianas
# alegres
# tristes
# multicolor
# anónimo
# complexas
# domésticas
# sós
# quarto
# magro
# absurdas
# pleno
# cheias
# ordinária
# suja
# decente
# irreais
# humana
# morais
# imorais
# baixos
# bons
# maus
# inatingíveis
# descontente
# sombrios
# mecânica
# constante
# grande
# novo
# rubro
# cruel
# delicioso
# nu
# quente
# ruidoso
# mecânico
# dinâmico
# mínimos
# brocas
# rotativas
# doentes
# There are 92 adverbs:
# totalmente
# fora
# dentro
# demasiadamente
# perto
# também
# outrora
# talvez
# fisicamente
# completamente
# exageradamente
# vagamente
# nunca
# geralmente
# simplesmente
# afinal
# lá
# quando
# insinceramente
# pouco
# quase
# olá
# hoje
# ontem
# gloriosamente
# carnivoramente
# pervertidamente
# não
# casualmente
# tão
# misericordiosamente
# realmente
# debaixo
# através
# nem
# sempre
# maravilhosamente
# abaixo
# assim
# aqui
# ali
# acolá
# estridentemente
# já
#
#
#
# Analysing AC_V_Guardador_de_Rebanhos ...
# Heteronym: Alberto_Caeiro
# The poem has 701 words in total:
# The poem has 199 unique words (types):
# ['v', 'há', 'metafísica', 'bastante', 'em', 'não', 'pensar', 'nada', '.', 'o', 'que', 'penso', 'eu', 'de', 'mundo', '?', 'sei', 'lá', '!', 'se', 'adoecesse', 'pensaria', 'isso', 'ideia', 'tenho', 'as', 'coisas', 'opinião', 'sobre', 'causas', 'e', 'os', 'efeitos', 'meditado', 'deus', 'a', 'alma', 'criação', 'para', 'mim', 'é', 'fechar', 'olhos', 'correr', 'cortinas', 'minha', 'janela', '(', 'mas', 'ela', 'tem', ')', 'mistério', 'único', 'haver', 'quem', 'pense', 'está', 'sol', 'fecha', ',', 'começa', 'saber', 'muitas', 'cheias', 'calor', 'abre', 'vê', 'já', 'pode', 'porque', 'luz', 'vale', 'mais', 'pensamentos', 'todos', 'filósofos', 'poetas', 'sabe', 'faz', 'por', 'erra', 'comum', 'boa', 'têm', 'aquelas', 'árvores', 'serem', 'verdes', 'copadas', 'terem', 'ramos', 'dar', 'fruto', 'sua', 'hora', 'nos', 'nós', 'sabemos', 'elas', 'melhor', 'vivem', 'nem', 'sabem', '«', 'constituição', 'íntima', '»', 'sentido', 'íntimo', 'universo', 'tudo', 'isto', 'falso', 'quer', 'dizer', 'incrível', 'possa', 'essas', 'como', 'razões', 'fins', 'quando', 'começo', 'manhã', 'raiando', 'lados', 'um', 'vago', 'ouro', 'lustroso', 'vai', 'perdendo', 'escuridão', 'acrescentado', 'saúde', 'ou', 'levar', 'copo', 'água', 'fontes', 'nenhum', 'acredito', 'nunca', 'vi', 'ele', 'quisesse', 'acreditasse', 'sem', 'dúvida', 'viria', 'falar', 'comigo', 'entraria', 'porta', 'dentro', 'dizendo', 'me', "'", 'aqui', 'estou', 'talvez', 'ridículo', 'ouvidos', 'olhar', 'compreende', 'fala', 'com', 'modo', 'reparar', 'ensina', 'flores', 'montes', 'luar', 'então', 'toda', 'vida', 'uma', 'oração', 'missa', 'comunhão', 'lhe', 'chamo', ';', 'fez', 'ver', 'aparece', 'sendo', 'conheça', 'obedeçço', 'si', 'próprio', 'viver', 'espontaneamente', 'am', 'o-o', 'vendo', 'ouvindo', 'ando']
# There are 16 adjectives:
# único
# cheias
# comum
# boa
# verdes
# melhor
# íntima
# íntimo
# falso
# incrível
# vago
# lustroso
# ridículo
# There are 31 adverbs:
# bastante
# não
# lá
# já
# mais
# quando
# nunca
# dentro
# aqui
# talvez
# então
# espontaneamente
#
#
#
# Analysing AC_IX_Guardador_de_Rebanhos ...
# Heteronym: Alberto_Caeiro
# The poem has 112 words in total:
# The poem has 65 unique words (types):
# ['ix', 'sou', 'um', 'guardador', 'de', 'rebanhos', '.', 'o', 'rebanho', 'é', 'os', 'meus', 'pensamentos', 'e', 'são', 'todos', 'sensações', 'penso', 'com', 'olhos', 'ouvidos', 'as', 'mãos', 'pés', 'nariz', 'a', 'boca', 'pensar', 'uma', 'flor', 'vê', 'lla', 'cheirá', 'la', 'comer', 'fruto', 'saber', 'lhe', 'sentido', 'por', 'isso', 'quando', 'em', 'dia', 'calor', 'me', 'sinto', 'triste', 'gozá', 'lo', 'tanto', ',', 'deito', 'comprido', 'erva', 'fecho', 'quentes', 'todo', 'meu', 'corpo', 'deitado', 'realidade', 'sei', 'verdade', 'feliz']
# There are 4 adjectives:
# ix
# triste
# quentes
# feliz
# There are 2 adverbs:
# quando
# tanto
#
#
#
# Analysing FP_Quando_era_criança ...
# Heteronym: Fernando_Pessoa
# The poem has 53 words in total:
# The poem has 37 unique words (types):
# ['quando', 'era', 'criança', 'vivi', ',', 'sem', 'saber', 'só', 'para', 'hoje', 'ter', 'aquela', 'lembrança', '.', 'e', 'que', 'sinto', 'aquilo', 'fui', 'minha', 'vida', 'flui', 'feita', 'de', 'o', 'minto', 'mas', 'em', 'esta', 'prisão', 'livro', 'único', 'leio', 'sorriso', 'alheio', 'quem', 'então']
# There are 2 adjectives:
# único
# alheio
# There are 4 adverbs:
# só
# hoje
# então
#
#
#
# Analysing FP_Autopsicografia ...
# Heteronym: Fernando_Pessoa
# The poem has 75 words in total:
# The poem has 48 unique words (types):
# ['autopsicografia', 'o', 'poeta', 'é', 'um', 'fingidor', 'finge', 'tão', 'completamente', 'que', 'chega', 'a', 'fingir', 'dor', 'deveras', 'sente', '.', 'e', 'os', 'lêem', 'escreve', ',', 'em', 'lida', 'sentem', 'bem', 'não', 'as', 'duas', 'ele', 'teve', 'mas', 'só', 'eles', 'têm', 'assim', 'calhas', 'de', 'roda', 'gira', 'entreter', 'razão', 'esse', 'comboio', 'corda', 'se', 'chama', 'coração']
# There are 1 adjectives:
# There are 8 adverbs:
# tão
# completamente
# deveras
# bem
# não
# só
# assim
#
#
#
# Analysing FP_Isto ...
# Heteronym: Fernando_Pessoa
# The poem has 88 words in total:
# The poem has 52 unique words (types):
# ['isto', 'dizem', 'que', 'finjo', 'ou', 'minto', 'tudo', 'escrevo', '.', 'não', 'eu', 'simplesmente', 'sinto', 'com', 'a', 'imaginação', 'uso', 'o', 'coração', 'sonho', 'passo', ',', 'me', 'falha', 'finda', 'é', 'como', 'um', 'terraço', 'sobre', 'outra', 'coisa', 'ainda', 'essa', 'linda', 'por', 'isso', 'em', 'meio', 'de', 'está', 'pé', 'livre', 'meu', 'enleio', 'sério', 'sentir', '?', 'sinta', 'quem', 'lê', '!']
# There are 1 adjectives:
# linda
# There are 6 adverbs:
# não
# simplesmente
# como
# ainda
#
#
#
# Analysing FP_Quando_as_crianças_brincam ...
# Heteronym: Fernando_Pessoa
# The poem has 67 words in total:
# The poem has 45 unique words (types):
# ['quando', 'as', 'crianças', 'brincam', 'e', 'eu', 'oiço', 'brincar', ',', 'qualquer', 'coisa', 'em', 'minha', 'alma', 'começa', 'a', 'se', 'alegrar', '.', 'toda', 'aquela', 'infância', 'que', 'não', 'tive', 'me', 'vem', 'uma', 'onda', 'de', 'alegria', 'foi', 'ninguém', 'quem', 'fui', 'é', 'enigma', 'serei', 'visão', 'sou', 'o', 'menos', 'sinta', 'isto', 'coração']
# There are 0 adjectives:
# There are 4 adverbs:
# quando
# não
#
#
#
# Analysing FP_Gato_que_brincas_na_rua ...
# Heteronym: Fernando_Pessoa
# The poem has 77 words in total:
# The poem has 50 unique words (types):
# ['gato', 'que', 'brincas', 'em', 'a', 'rua', 'como', 'se', 'fosse', 'cama', ',', 'invejo', 'sorte', 'é', 'tua', 'porque', 'nem', 'chama', '.', 'bom', 'servo', 'de', 'as', 'leis', 'fatais', 'regem', 'pedras', 'e', 'gentes', 'tens', 'instintos', 'gerais', 'sentes', 'só', 'o', 'és', 'feliz', 'assim', 'todo', 'nada', 'teu', 'eu', 'vejo', 'me', 'estou', 'sem', 'mim', 'conheçço', 'não', 'sou']
# There are 4 adjectives:
# bom
# fatais
# gerais
# feliz
# There are 3 adverbs:
# só
# assim
# não
#
#
#
# Done!
